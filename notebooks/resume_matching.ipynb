# %%
import nltk
import re
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load Data

with open("../data/sample_resume.txt", "r") as f:
    resume_text = f.read()

with open("../data/sample_job_description.txt", "r") as f:
    job_text = f.read()

resume_text, job_text
# Out:
# ('Experienced Python developer with strong knowledge of Machine Learning,\nData Analysis, SQL, and NLP. Worked on fraud detection and churn prediction\nprojects. Familiar with Pandas, NumPy, Scikit-learn, and Streamlit.',
#  'We are looking for a Python developer with experience in Machine Learning,\nNatural Language Processing, data preprocessing, and model evaluation.\nKnowledge of SQL and deployment tools is a plus.')

# %%
# Text Cleaning

def clean_text(text):
    text = text.lower()
    text = re.sub(r"\d+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    return text

resume_clean = clean_text(resume_text)
job_clean = clean_text(job_text)

# %%
# TF-IDF Vectorization

vectorizer = TfidfVectorizer(stop_words="english")

vectors = vectorizer.fit_transform([resume_clean, job_clean])

# %%
# Cosine Similarity Calculation

similarity_score = cosine_similarity(vectors[0], vectors[1])[0][0]
print(f"Resume–Job Match Score: {similarity_score*100:.2f}%")
# Out:
# Resume–Job Match Score: 21.58%
